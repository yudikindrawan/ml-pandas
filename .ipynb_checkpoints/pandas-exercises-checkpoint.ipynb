# %%
import pandas as pd

# %%
colors = pd.Series(['red', 'blue', 'yellow'])

# %%
colors
# Out:
# 0       red
# 1      blue
# 2    yellow
# dtype: object

# %%
cars = pd.Series(['toyota', 'nissan', 'bmw'])

# %%
cars
# Out:
# 0    toyota
# 1    nissan
# 2       bmw
# dtype: object

# %%
car_data = pd.DataFrame({"Car Make" : cars, "Color" : colors})
car_data
# Out:
#   Car Make   Color
# 0   toyota     red
# 1   nissan    blue
# 2      bmw  yellow

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("car-sales2.csv")

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
number_series = pd.Series([243, 898, 1233])
number_series.mean()
# Out:
# np.float64(791.3333333333334)

# %%
number_series_sum = pd.Series([33, 54, 99])
number_series_sum.sum()
# Out:
# np.int64(186)

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# np.float64(78601.4)

# %%
# car_sales[car_sales['Odometer (KM)'] > 100000]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White           True      4   $4,000.00
# 1   Honda    Red           True      4   $5,000.00
# 2  Toyota   Blue           True      3   $7,000.00
# 3     BMW  Black           True      5  $22,000.00
# 4  Nissan  White           True      4   $3,500.00
# 5  Toyota  Green           True      4   $4,500.00
# 6   Honda   Blue           True      4   $7,500.00
# 7   Honda   Blue           True      4   $7,000.00
# 8  Toyota  White           True      4   $6,250.00
# 9  Nissan  White           True      4   $9,700.00

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby(car_sales['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib as plt

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
car_sales['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 car_sales['Price'].plot()
#
# File D:\WORK\Anaconda\machine-learning\sample-project\env\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File D:\WORK\Anaconda\machine-learning\sample-project\env\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'].info
# Out:
# <bound method Series.info of 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object>

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '',  regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# import missing data
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_sales_missing.isnull().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
# car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)
# car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Odometer (KM)
# 0  Toyota  White  150043.000000    4.0   $4,000  150043.000000
# 1   Honda    Red   87899.000000    4.0   $5,000   87899.000000
# 2  Toyota   Blue   92302.666667    3.0   $7,000   92302.666667
# 3     BMW  Black   11179.000000    5.0  $22,000   11179.000000
# 4  Nissan  White  213095.000000    4.0   $3,500  213095.000000
# 5  Toyota  Green   92302.666667    4.0   $4,500   92302.666667
# 6   Honda    NaN   92302.666667    4.0   $7,500   92302.666667
# 7   Honda   Blue   92302.666667    4.0      NaN   92302.666667
# 8  Toyota  White   60000.000000    NaN      NaN   60000.000000
# 9     NaN  White   31600.000000    4.0   $9,700   31600.000000

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Odometer (KM)
# 0  Toyota  White  150043.000000    4.0   $4,000  150043.000000
# 1   Honda    Red   87899.000000    4.0   $5,000   87899.000000
# 2  Toyota   Blue   92302.666667    3.0   $7,000   92302.666667
# 3     BMW  Black   11179.000000    5.0  $22,000   11179.000000
# 4  Nissan  White  213095.000000    4.0   $3,500  213095.000000
# 5  Toyota  Green   92302.666667    4.0   $4,500   92302.666667

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales['Seats'] = 5

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000      5
# 1   honda    Red          87899      4   5000      5
# 2  toyota   Blue          32549      3   7000      5
# 3     bmw  Black          11179      5  22000      5
# 4  nissan  White         213095      4   3500      5
# 5  toyota  Green          99213      4   4500      5
# 6   honda   Blue          45698      4   7500      5
# 7   honda   Blue          54738      4   7000      5
# 8  toyota  White          60000      4   6250      5
# 9  nissan  White          31600      4   9700      5

# %%
engine_sizes = [1.3, 4.3, 2.3, 3.3, 3.0, 2.3, 1.4, 1.7, 2.5, 3.1]
car_sales['Engine Size'] = engine_sizes
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1

# %%
car_sales['Price per KM'] = car_sales['Price'] / car_sales['Odometer (KM)']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1
#
#    Price per KM
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962

# %%
car_sales['Price per KM'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\1350845676.py in ?()
# ----> 1 car_sales['Price per KM'].drop()
#
# D:\WORK\Anaconda\machine-learning\sample-project\env\Lib\site-packages\pandas\core\series.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5352         falcon  speed     320.0
#    5353                 length      0.3
#    5354         dtype: float64
#    5355         """
# -> 5356         return super().drop(
#    5357             labels=labels,
#    5358             axis=axis,
#    5359             index=index,
#
# D:\WORK\Anaconda\machine-learning\sample-project\env\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4776             axes = {"index": index}
#    4777             if self.ndim == 2:
# ...

# %%
car_sales.drop('Price per KM', axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1

# %%
fuel = [5, 4, 5, 4, 3, 8, 9, 5, 2, 1]
car_sales['Fuel per KM'] = fuel
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1
#
#    Price per KM  Fuel per KM
# 0      0.026659            5
# 1      0.056883            4
# 2      0.215060            5
# 3      1.967976            4
# 4      0.016425            3
# 5      0.045357            8
# ...

# %%
car_sales['Total fuel'] = car_sales['Fuel per KM'] * car_sales['Odometer (KM)']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1
#
#    Price per KM  Fuel per KM  Total fuel
# 0      0.026659            5      750215
# 1      0.056883            4      351596
# 2      0.215060            5      162745
# 3      1.967976            4       44716
# ...

# %%
car_sales = car_sales.rename(columns={"Total fuel" : "Total fuel used"})
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          4.3
# 2  toyota   Blue          32549      3   7000      5          2.3
# 3     bmw  Black          11179      5  22000      5          3.3
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.3
# 6   honda   Blue          45698      4   7500      5          1.4
# 7   honda   Blue          54738      4   7000      5          1.7
# 8  toyota  White          60000      4   6250      5          2.5
# 9  nissan  White          31600      4   9700      5          3.1
#
#    Price per KM  Fuel per KM  Total fuel used
# 0      0.026659            5           750215
# 1      0.056883            4           351596
# 2      0.215060            5           162745
# 3      1.967976            4            44716
# ...
